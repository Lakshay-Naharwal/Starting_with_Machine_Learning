# %% [markdown]
# # 📊 Data Fetching Pipeline Overview
#
# This notebook demonstrates **three fundamental approaches** to data collection:
#
# 1. 🗄️ **Database Queries** - Fetching structured data from MySQL databases
# 2. 🌐 **API Integration** - Retrieving data through RESTful API endpoints
# 3. 🕸️ **Web Scraping** - Extracting data directly from HTML websites
#
# ---

# %% [markdown]
# ## 1️⃣ 🗄️ Fetching Data from Database (MySQL)
#
# ### 📦 **Pandas Library**
# **Purpose:** Core Python library for data manipulation and analysis
# **Used for:** DataFrame operations, SQL integration, data cleaning
# **Import:** `import pandas as pd`

# %%
import pandas as pd

# %% [markdown]
# ### 🔌 **MySQL Connection Dependencies**
# **Installing Required Packages:**
# - `mysql-connector` - Official MySQL driver for Python
# - `sqlalchemy` - SQL toolkit and ORM
# - `pymysql` - Pure Python MySQL client library

# %%
# !pip install mysql.connector
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: mysql.connector in c:\users\asus\anaconda3\envs\camp\lib\site-packages (2.2.9)
# Requirement already satisfied: sqlalchemy in c:\users\asus\anaconda3\envs\camp\lib\site-packages (2.0.45)
# Requirement already satisfied: greenlet>=1 in c:\users\asus\anaconda3\envs\camp\lib\site-packages (from sqlalchemy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\asus\anaconda3\envs\camp\lib\site-packages (from sqlalchemy) (4.15.0)

# %% [markdown]
# ### 📥 **Import MySQL Connector**
# **Library:** `mysql.connector`
# **Purpose:** Enables Python to communicate with MySQL database servers
# **Key Functions:** Establishing connections, executing queries, fetching results

# %%
import mysql.connector

# %% [markdown]
# ### 🔗 **Establish Database Connection**
# **Function:** `mysql.connector.connect()`
# **Parameters:**
# - `host` - Database server address (localhost for local development)
# - `user` - MySQL username
# - `password` - Authentication password
# - `database` - Target database name
#
# **Returns:** Connection object for executing SQL queries

# %%
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='',
    database='world'
)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\anaconda3\envs\camp\Lib\site-packages\mysql\connector\network.py:509, in MySQLTCPSocket.open_connection(self)
#     508     self.sock.settimeout(self._connection_timeout)
# --> 509     self.sock.connect(sockaddr)
#     510 except IOError as err:
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 conn = mysql.connector.connect(
#       2     host='localhost',
#       3     user='root',
#       4     password='',
#       5     database='world'
#       6 )
#
# File ~\anaconda3\envs\camp\Lib\site-packages\mysql\connector\__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File ~\anaconda3\envs\camp\Lib\site-packages\mysql\connector\connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      92 self._pool_config_version = None
#      94 if len(kwargs) > 0:
# ---> 95     self.connect(**kwargs)
#
# File ~\anaconda3\envs\camp\Lib\site-packages\mysql\connector\abstracts.py:716, in MySQLConnectionAbstract.connect(self, **kwargs)
#     713     self.config(**kwargs)
#     715 self.disconnect()
# --> 716 self._open_connection()
#     717 self._post_connection()
#
# File ~\anaconda3\envs\camp\Lib\site-packages\mysql\connector\connection.py:206, in MySQLConnection._open_connection(self)
#     204 self._protocol = MySQLProtocol()
#     205 self._socket = self._get_connection()
# --> 206 self._socket.open_connection()
#     207 self._do_handshake()
#     208 self._do_auth(self._user, self._password,
#     209               self._database, self._client_flags, self._charset_id,
#     210               self._ssl)
#
# File ~\anaconda3\envs\camp\Lib\site-packages\mysql\connector\network.py:511, in MySQLTCPSocket.open_connection(self)
#     509     self.sock.connect(sockaddr)
#     510 except IOError as err:
# --> 511     raise errors.InterfaceError(
#     512         errno=2003, values=(self.get_address(), _strioerror(err)))
#     513 except Exception as err:
#     514     raise errors.OperationalError(str(err))
#
# InterfaceError: 2003: Can't connect to MySQL server on 'localhost:3306' (10061 No connection could be made because the target machine actively refused it)

# %% [markdown]
# ### 📊 **Execute SQL Query & Load Data**
# **Function:** `pd.read_sql_query()`
# **Purpose:** Executes SQL query and returns results as pandas DataFrame
# **Parameters:**
# - SQL query string
# - Database connection object
#
# **Use Case:** Fetching filtered data (e.g., US cities from 'city' table)

# %%
pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'USA'", conn)

# %% [markdown]
# ---
#
# ✅ **Section 1 Complete:** Database Query Mastered!
# ⬇️ **Next:** API Data Retrieval
#
# ---

# %% [markdown]
# ---
#
# ## 2️⃣ 🌐 Fetching Data From API
#
# ### 📦 **Requests Library**
# **Purpose:** HTTP library for making API calls
# **Used for:** Sending GET/POST requests to web APIs and handling responses
# **Key Methods:** `get()`, `post()`, `json()`

# %% [markdown]
# ### 🌐 **Making API Request**
# **Process Flow:**
# 1. 📍 **URL** - API endpoint address
# 2. 🔑 **Headers** - Authentication keys (x-rapidapi-key, x-rapidapi-host)
# 3. ⚙️ **Query Parameters** - Search filters, pagination, sorting options
# 4. 📡 **Send Request** - `requests.get()` with URL, headers, and params
# 5. 📥 **Parse Response** - Convert JSON response to DataFrame using `response.json()`
#
# **Example:** Fetching anime data from RapidAPI

# %%
import requests

url = "https://anime-db.p.rapidapi.com/anime"

querystring = {"page":"1","size":"10","search":"Fullmetal","genres":"Fantasy,Drama","sortBy":"ranking","sortOrder":"asc"}

headers = {
	"x-rapidapi-key": "5eadd6bc7emsh83392246ef39d66p14ffd4jsn9887126a5414",
	"x-rapidapi-host": "anime-db.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

df=pd.DataFrame(response.json()['data'])

# %%
print(df.shape)

# %% [markdown]
# ---
#
# ✅ **Section 2 Complete:** API Integration Done!
# ⬇️ **Next:** Web Scraping Techniques
#
# ---

# %% [markdown]
# ---
#
# ## 3️⃣ 🕸️ Fetching Data From Web Scraping
#
# ### 📦 **Web Scraping Libraries**
# **Required Packages:**
#
# **🐍 BeautifulSoup (bs4)**
# - HTML/XML parser for extracting data from web pages
# - Navigates and searches the parse tree
# - Usage: `from bs4 import BeautifulSoup`
#
# **🔧 lxml**
# - Fast XML and HTML parser
# - Backend parser used by BeautifulSoup
# - Better performance for large documents
#
# **🌐 requests**
# - HTTP library to fetch webpage HTML content
# - Combined with BeautifulSoup for complete scraping workflow

# %%
import pandas as pd
import requests as re
from bs4 import BeautifulSoup
# !pip install lxml
import lxml
# Out:
# Requirement already satisfied: lxml in c:\users\asus\anaconda3\envs\camp\lib\site-packages (6.0.2)

# %% [markdown]
# ### 🎭 **User-Agent Header**
# **Purpose:** Tells the website we're visiting that this is a browser request
# **Why needed:** Helps avoid "Access Denied" (403) errors
# **Usage:** Pass in `headers` parameter to `requests.get()`

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

# %% [markdown]
# ### 📡 **Fetch Webpage HTML**
# **Function:** `requests.get()`
# **Purpose:** Fetches raw HTML data from the given URL
# **Returns:** Response object with `.text` attribute containing HTML

# %%
webpage =requests.get('https://www.ambitionbox.com/list-of-companies?page=1',headers=headers).text

# %% [markdown]
# ### 🍜 **Parse HTML with BeautifulSoup**
# **Function:** `BeautifulSoup(webpage, 'lxml')`
# **Purpose:** Converts unstructured HTML into structured, searchable tree
# **Parser:** 'lxml' tells BeautifulSoup that data is HTML format
# **Why needed:** Makes it easier to navigate and extract specific data

# %%
soup = BeautifulSoup(webpage , 'lxml')

# %% [markdown]
# ### 🔍 **Find All Company Cards**
# **Function:** `soup.find_all('div', class_='companyCardWrapper')`
# **Purpose:** Finds all company card containers on the page
# **Returns:** List of all matching `<div>` elements
# **Usage:** First step to extract multiple companies from single page

# %%
company = soup.find_all('div', class_='companyCardWrapper')
len(company)
# Out:
# 20

# %% [markdown]
# ### 📝 **Extract Company Details**
# **Process:** Loop through each company card and extract:
# - **Company Name** - Using `find('h2')`
# - **Rating** - From `rating_star_container` class
# - **Number of Reviews** - From `companyRatingCount` class
# - **Company Type & Location** - From `interLinking` class (split by `|`)
#
# **Data Storage:** Lists that will be converted to DataFrame

# %%
names=[]
rating=[]
No_Of_Reviews=[]
ctype=[]
locations=[]
company_type=''
location=''

for i in company:
    names.append(i.find('h2').text.strip())
    rating.append(i.find('div', class_='rating_star_container').text.strip())
    No_Of_Reviews.append(i.find('span' , class_='companyCardWrapper__companyRatingCount').text.strip())
    misc_info = i.find('span', class_='companyCardWrapper__interLinking')
    if misc_info:
    # Split by "|" to separate type and location
        parts = misc_info.text.split('|')
        
        # Company Type (first part)
        company_type = parts[0].strip() if len(parts) > 0 else ''
        ctype.append(company_type)
        
        # Location (second part)
        location = parts[1].strip() if len(parts) > 1 else ''
        locations.append(location)
    else:
        ctype.append('')
        locations.append('')

# %%
names
# Out:
# ['TCS',
#  'Accenture',
#  'Wipro',
#  'Cognizant',
#  'Capgemini',
#  'HDFC Bank',
#  'Infosys',
#  'ICICI Bank',
#  'HCLTech',
#  'Tech Mahindra',
#  'Genpact',
#  'Teleperformance',
#  'Axis Bank',
#  'Jio',
#  'Concentrix Corporation',
#  'Amazon',
#  'iEnergizer',
#  'Reliance Retail',
#  'LTIMindtree',
#  'IBM']

# %%
rating
# Out:
# ['3.3',
#  '3.7',
#  '3.6',
#  '3.6',
#  '3.7',
#  '3.8',
#  '3.5',
#  '4.0',
#  '3.4',
#  '3.4',
#  '3.6',
#  '3.8',
#  '3.6',
#  '4.4',
#  '3.6',
#  '3.9',
#  '4.6',
#  '3.9',
#  '3.6',
#  '3.9']

# %%
No_Of_Reviews
# Out:
# ['(1.1L)',
#  '(71.1k)',
#  '(63.4k)',
#  '(59.7k)',
#  '(51.6k)',
#  '(50.6k)',
#  '(47.2k)',
#  '(45.2k)',
#  '(44.5k)',
#  '(42.3k)',
#  '(40.8k)',
#  '(36.5k)',
#  '(32.3k)',
#  '(32.2k)',
#  '(31.5k)',
#  '(30.7k)',
#  '(27.1k)',
#  '(26.9k)',
#  '(25.8k)',
#  '(25.3k)']

# %%
ctype
# Out:
# ['IT Services & Consulting',
#  'IT Services & Consulting',
#  'IT Services & Consulting',
#  'IT Services & Consulting',
#  'IT Services & Consulting',
#  'Banking',
#  'IT Services & Consulting',
#  'Banking',
#  'IT Services & Consulting',
#  'IT Services & Consulting',
#  'IT Services & Consulting',
#  'BPO',
#  'Banking',
#  'Telecom',
#  'BPO',
#  'Internet',
#  'BPO',
#  'Retail',
#  'IT Services & Consulting',
#  'IT Services & Consulting']

# %%
locations
# Out:
# ['Bangalore / Bengaluru +439 other locations',
#  'Bangalore / Bengaluru +255 other locations',
#  'Hyderabad / Secunderabad +370 other locations',
#  'Hyderabad / Secunderabad +229 other locations',
#  'Bangalore / Bengaluru +184 other locations',
#  'Mumbai +1821 other locations',
#  'Bangalore / Bengaluru +246 other locations',
#  'Mumbai +1438 other locations',
#  'Chennai +226 other locations',
#  'Hyderabad / Secunderabad +331 other locations',
#  'Hyderabad / Secunderabad +182 other locations',
#  'Mumbai +254 other locations',
#  'Mumbai +1499 other locations',
#  'Mumbai +1895 other locations',
#  'Bangalore / Bengaluru +177 other locations',
#  'Bangalore / Bengaluru +518 other locations',
#  'Noida +51 other locations',
#  'Mumbai +1152 other locations',
#  'Bangalore / Bengaluru +146 other locations',
#  'Bangalore / Bengaluru +160 other locations']

# %% [markdown]
# ### 📊 **Create DataFrame from Lists**
# **Function:** `pd.DataFrame()`
# **Purpose:** Converts extracted lists into structured tabular data
# **Columns Created:**
# - `Company_Name` - Company name
# - `Rating` - Rating score
# - `No_Of_Reviews` - Review count
# - `Company_Type` - Business category
# - `Location` - Office locations

# %%
df = pd.DataFrame({
    'Company_Name': names,
    'Rating': rating,
    'No_Of_Reviews': No_Of_Reviews,
    'Company_Type': ctype,
    'Location': locations
})

# %%
df
# Out:
#               Company_Name Rating No_Of_Reviews              Company_Type  \
# 0                      TCS    3.3        (1.1L)  IT Services & Consulting
# 1                Accenture    3.7       (71.1k)  IT Services & Consulting
# 2                    Wipro    3.6       (63.4k)  IT Services & Consulting
# 3                Cognizant    3.6       (59.7k)  IT Services & Consulting
# 4                Capgemini    3.7       (51.6k)  IT Services & Consulting
# 5                HDFC Bank    3.8       (50.6k)                   Banking
# 6                  Infosys    3.5       (47.2k)  IT Services & Consulting
# 7               ICICI Bank    4.0       (45.2k)                   Banking
# 8                  HCLTech    3.4       (44.5k)  IT Services & Consulting
# 9            Tech Mahindra    3.4       (42.3k)  IT Services & Consulting
# 10                 Genpact    3.6       (40.8k)  IT Services & Consulting
# 11         Teleperformance    3.8       (36.5k)                       BPO
# 12               Axis Bank    3.6       (32.3k)                   Banking
# 13                     Jio    4.4       (32.2k)                   Telecom
# 14  Concentrix Corporation    3.6       (31.5k)                       BPO
# 15                  Amazon    3.9       (30.7k)                  Internet
# 16              iEnergizer    4.6       (27.1k)                       BPO
# 17         Reliance Retail    3.9       (26.9k)                    Retail
# 18             LTIMindtree    3.6       (25.8k)  IT Services & Consulting
# 19                     IBM    3.9       (25.3k)  IT Services & Consulting
#
#                                          Location
# 0      Bangalore / Bengaluru +439 other locations
# 1      Bangalore / Bengaluru +255 other locations
# 2   Hyderabad / Secunderabad +370 other locations
# 3   Hyderabad / Secunderabad +229 other locations
# 4      Bangalore / Bengaluru +184 other locations
# 5                    Mumbai +1821 other locations
# 6      Bangalore / Bengaluru +246 other locations
# 7                    Mumbai +1438 other locations
# 8                    Chennai +226 other locations
# 9   Hyderabad / Secunderabad +331 other locations
# 10  Hyderabad / Secunderabad +182 other locations
# 11                    Mumbai +254 other locations
# 12                   Mumbai +1499 other locations
# 13                   Mumbai +1895 other locations
# 14     Bangalore / Bengaluru +177 other locations
# 15     Bangalore / Bengaluru +518 other locations
# 16                      Noida +51 other locations
# 17                   Mumbai +1152 other locations
# 18     Bangalore / Bengaluru +146 other locations
# 19     Bangalore / Bengaluru +160 other locations

# %% [markdown]
# ---
#
# ## 🔁 **Scaling Up: Multiple Pages**
#
# ### 🔄 **Loop Through All Pages**
# **Strategy:** Iterate from page 1 to page 330 to collect all company data
# **Process:**
# 1. Generate URL for each page
# 2. Fetch and parse HTML
# 3. Extract company data
# 4. Append to combined list
# 5. Convert to final DataFrame

# %%
import pandas as pd
import requests 
from bs4 import BeautifulSoup



final = pd.DataFrame()

for j in range (1,501):
    url='https://www.ambitionbox.com/list-of-companies?page={}'.format(j)
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    webpage =requests.get(url,headers=headers).text
    soup = BeautifulSoup(webpage , 'lxml')
    company = soup.find_all('div', class_='companyCardWrapper')
   
    names=[]
    rating=[]
    No_Of_Reviews=[]
    ctype=[]
    locations=[]
    company_type=''
    location=''
    for i in company:

        names.append(i.find('h2').text.strip())
        rating.append(i.find('div', class_='rating_star_container').text.strip())
        No_Of_Reviews.append(i.find('span' , class_='companyCardWrapper__companyRatingCount').text.strip())
        misc_info = i.find('span', class_='companyCardWrapper__interLinking')
        if misc_info:
        # Split by "|" to separate type and location
            parts = misc_info.text.split('|')
            
            # Company Type (first part)
            company_type = parts[0].strip() if len(parts) > 0 else ''
            ctype.append(company_type)
            
            # Location (second part)
            location = parts[1].strip() if len(parts) > 1 else ''
            locations.append(location)
        else:
            ctype.append('')
            locations.append('')

    df = pd.DataFrame({
        'Company_Name': names,
        'Rating': rating,
        'No_Of_Reviews': No_Of_Reviews,
        'Company_Type': ctype,
        'Location': locations
    })

    final = pd.concat([final, df], ignore_index=True)

# %%
final
# Out:
#                       Company_Name Rating No_Of_Reviews  \
# 0                              TCS    3.3        (1.1L)
# 1                        Accenture    3.7       (71.1k)
# 2                            Wipro    3.6       (63.4k)
# 3                        Cognizant    3.6       (59.7k)
# 4                        Capgemini    3.7       (51.6k)
# ...                            ...    ...           ...
# 9995  Eduquity Career Technologies    3.4         (106)
# 9996            D Y Patil Hospital    3.9         (106)
# 9997            Gulermak-Sam India    4.1         (106)
# 9998    CRY - Child Rights and You    4.0         (106)
# 9999                 Lanarsy Infra    3.2         (106)
#
#                     Company_Type  \
# 0       IT Services & Consulting
# 1       IT Services & Consulting
# 2       IT Services & Consulting
# 3       IT Services & Consulting
# 4       IT Services & Consulting
# ...                          ...
# 9995                 Recruitment
# 9996                  Healthcare
# 9997    Surat +9 other locations
# 9998                  Non-Profit
# 9999  Engineering & Construction
#
#                                            Location
# 0        Bangalore / Bengaluru +439 other locations
# 1        Bangalore / Bengaluru +255 other locations
# 2     Hyderabad / Secunderabad +370 other locations
# 3     Hyderabad / Secunderabad +229 other locations
# 4        Bangalore / Bengaluru +184 other locations
# ...                                             ...
# 9995      Bangalore / Bengaluru +14 other locations
# 9996                      Mumbai +7 other locations
# 9997
# 9998                      Mumbai +9 other locations
# 9999   Hyderabad / Secunderabad +15 other locations
#
# [10000 rows x 5 columns]

# %%
df
# Out:
#                      Company_Name Rating No_Of_Reviews  \
# 0   Humana People to People India    4.2         (106)
# 1               Anonymous Content    4.1         (106)
# 2                    Migsun Group    3.0         (106)
# 3              Bharat Parenterals    2.9         (106)
# 4                         Kelvion    3.8         (106)
# 5                            QDVC    4.8         (106)
# 6            Eastern Book Company    3.2         (106)
# 7         Axiom Energy Conversion    3.1         (106)
# 8                  Airtel X- Labs    3.1         (106)
# 9                CIBERsites India    3.7         (106)
# 10                           GOOD    4.4         (106)
# 11    Prodata Management Services    3.4         (106)
# 12           Sekhmet Technologies    3.8         (106)
# 13            Narayana Jr College    3.4         (106)
# 14                       YRG CARE    4.1         (106)
# 15   Eduquity Career Technologies    3.4         (106)
# 16             D Y Patil Hospital    3.9         (106)
# 17             Gulermak-Sam India    4.1         (106)
# 18     CRY - Child Rights and You    4.0         (106)
# 19                  Lanarsy Infra    3.2         (106)
#
#                              Company_Type  \
# 0                              Non-Profit
# 1                Pune +19 other locations
# 2                             Real Estate
# 3                                  Pharma
# 4                    Industrial Machinery
# 5              Engineering & Construction
# 6                   Printing & Publishing
# 7                                   Power
# 8   Gurgaon / Gurugram +6 other locations
# 9                IT Services & Consulting
# 10                Marketing & Advertising
# 11                                    BPO
# 12               IT Services & Consulting
# 13                   Education & Training
# 14            Chennai +26 other locations
# 15                            Recruitment
# 16                             Healthcare
# 17               Surat +9 other locations
# 18                             Non-Profit
# 19             Engineering & Construction
#
#                                         Location
# 0                  New Delhi +32 other locations
# 1
# 2                   Ghaziabad +7 other locations
# 3                    Vadodara +9 other locations
# 4                       Pune +12 other locations
# 5                        Doha +6 other locations
# 6                     Lucknow +9 other locations
# 7   Hyderabad / Secunderabad +15 other locations
# 8
# 9       Bangalore / Bengaluru +5 other locations
# 10     Bangalore / Bengaluru +30 other locations
# 11                     Mumbai +9 other locations
# 12         Gurgaon / Gurugram +8 other locations
# 13  Hyderabad / Secunderabad +25 other locations
# 14
# 15     Bangalore / Bengaluru +14 other locations
# 16                     Mumbai +7 other locations
# 17
# 18                     Mumbai +9 other locations
# 19  Hyderabad / Secunderabad +15 other locations

# %% [markdown]
# ### 💾 **Save Data to CSV**
# **Function:** `final.to_csv('ambitionbox_companies1.csv')`
# **Purpose:** Exports DataFrame to CSV file for future use
# **Output:** CSV file with 10,000+ company records
# **Use Cases:** Data analysis, ML models, business intelligence

# %%
final.to_csv('ambitionbox_companies1.csv')

# %% [markdown]
# ---
#
# ## 🎉 **Congratulations!**
#
# You've learned **three powerful data collection methods**:
#
# ✅ **Database Queries** - Structured data from SQL databases
# ✅ **API Integration** - JSON data from RESTful APIs
# ✅ **Web Scraping** - Data extraction from HTML websites
#
# ### 🚀 **Next Steps:**
# - Data Cleaning & Preprocessing
# - Exploratory Data Analysis (EDA)
# - Feature Engineering
# - Machine Learning Model Building
#
# ---
#
# **Happy Data Science! 📊🐍**
